# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.time import Time

# %matplotlib notebook
data = np.genfromtxt(r"D:\Downloads\table2.dat")
Filter_col = data[:,0]
B_data = data[np.isclose(Filter_col, 1)]
V_data = data[np.isclose(Filter_col, 2)]
#print(data)
plt.figure()
time = 2456000 +2347.0119+ V_data[:,1]*12.94379

plt.errorbar(time, V_data[:,2], yerr=V_data[:,3], ls="None")
time = 2456000 +2347.0119+ B_data[:,1]*12.94379
plt.errorbar(time, B_data[:,2], yerr=B_data[:,3], ls="None")

#plt.xlim(2456400, 2456800)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ErrorbarContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.time import Time

# %matplotlib notebook
data = np.genfromtxt(r"D:\Downloads\table2.dat")
print(data)
data = np.delete(data, 0, axis = 0)
print(data)
# Out:
# [[1.0000e+00 4.1000e-03 4.0211e+00 1.2000e-02 6.0000e+00]
#  [1.0000e+00 1.4700e-02 4.0335e+00 9.6000e-03 5.0000e+00]
#  [1.0000e+00 2.5200e-02 4.0462e+00 1.0200e-02 8.0000e+00]
#  ...
#  [3.0000e+00 9.7430e-01 4.3114e+00 1.1600e-02 7.0000e+00]
#  [3.0000e+00 9.8440e-01 4.3245e+00 1.3000e-02 5.0000e+00]
#  [3.0000e+00 9.9440e-01 4.3360e+00 6.6000e-03 6.0000e+00]]
# [[1.0000e+00 1.4700e-02 4.0335e+00 9.6000e-03 5.0000e+00]
#  [1.0000e+00 2.5200e-02 4.0462e+00 1.0200e-02 8.0000e+00]
#  [1.0000e+00 3.5900e-02 4.0018e+00 1.6700e-02 7.0000e+00]
#  ...
#  [3.0000e+00 9.7430e-01 4.3114e+00 1.1600e-02 7.0000e+00]
#  [3.0000e+00 9.8440e-01 4.3245e+00 1.3000e-02 5.0000e+00]
#  [3.0000e+00 9.9440e-01 4.3360e+00 6.6000e-03 6.0000e+00]]

# %%
# Out:
# [4.1000e-03 4.0211e+00 1.2000e-02 ... 4.3360e+00 6.6000e-03 6.0000e+00]
# [4.1000e-03 4.0211e+00 1.2000e-02 ... 4.3360e+00 6.6000e-03 6.0000e+00]
